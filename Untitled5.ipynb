# %% [markdown]
# <a href="https://colab.research.google.com/github/vivianeborges353-commits/se-sen-o/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
idade=int(input("digite a sua idade:"))
if idade >=18:
  print("você é maior de iade")
else:
  print("você é menor de idade")
# Out:
# digite a sua idade:15
# você é menor de idade

# %%
idade=32
if idade < 16:
  print("você é menor de idade")
elif idade >= 16 and idade < 18:
  print("voto opicional")
elif idade >= 18 and idade <= 75:
  print("voto obrigatório")
else:
  print("nenhuma das opções")
# Out:
# voto obrigatório
