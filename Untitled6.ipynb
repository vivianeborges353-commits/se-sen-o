# %% [markdown]
# <a href="https://colab.research.google.com/github/vivianeborges353-commits/se-sen-o/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
entrega=input("digite o tipo de entrega:")
if entrega=="padrão":
  print("entrega padrão:R$10,00")
elif entrega== "expresso":
  print("entrega expresso: R$20,00")
else:
  print("opção de entrega inválida")
# Out:
# digite o tipo de entrega:expresso
# entrega expresso: R$20,00
